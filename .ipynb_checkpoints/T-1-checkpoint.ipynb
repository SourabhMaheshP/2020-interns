# %%
import json
import pandas as pd

# %%
file = open('data.json')
data = json.load(file)

# %%
data
# Out:
# {'rates': {'2019-02-05': {'CAD': 1.4996,
#    'HKD': 8.9623,
#    'ISK': 137.0,
#    'PHP': 59.743,
#    'DKK': 7.465,
#    'HUF': 317.41,
#    'CZK': 25.697,
#    'AUD': 1.5771,
#    'RON': 4.7455,
#    'SEK': 10.3998,
#    'IDR': 15964.21,
#    'INR': 81.8395,
#    'BRL': 4.1942,
#    'RUB': 74.8209,
#    'HRK': 7.412,
#    'JPY': 125.59,
#    'THB': 35.725,
#    'CHF': 1.1436,
#    'SGD': 1.5445,
#    'PLN': 4.2872,
#    'BGN': 1.9558,
#    'TRY': 5.9444,
#    'CNY': 7.6938,
#    'NOK': 9.6783,
#    'NZD': 1.6556,
#    'ZAR': 15.2773,
#    'USD': 1.1423,
#    'MXN': 21.7407,
#    'ILS': 4.1251,
#    'GBP': 0.87803,
#    'KRW': 1276.75,
#    'MYR': 4.6628},
#   '2019-06-28': {'CAD': 1.4893,
#    'HKD': 8.8866,
#    'ISK': 141.7,
#    'PHP': 58.335,
#    'DKK': 7.4636,
#    'HUF': 323.39,
#    'CZK': 25.447,
#    'AUD': 1.6244,
#    'RON': 4.7343,
#    'SEK': 10.5633,
#    'IDR': 16083.35,
#    'INR': 78.524,
#    'BRL': 4.3511,
#    'RUB': 71.5975,
#    'HRK': 7.3973,
# ...

# %%
df_data = pd.DataFrame(data['rates'])
df_data
# Out:
#       2019-02-05   2019-06-28   2019-12-30   2019-07-15   2019-11-25  \
# CAD      1.49960      1.48930      1.46210      1.46840      1.46480
# HKD      8.96230      8.88660      8.71330      8.82010      8.61640
# ISK    137.00000    141.70000    135.80000    141.70000    135.90000
# PHP     59.74300     58.33500     56.78400     57.50600     55.91500
# DKK      7.46500      7.46360      7.46970      7.46690      7.47160
# HUF    317.41000    323.39000    331.04000    325.66000    335.23000
# CZK     25.69700     25.44700     25.46300     25.56900     25.48500
# AUD      1.57710      1.62440      1.59920      1.60230      1.62320
# RON      4.74550      4.73430      4.78210      4.73330      4.77230
# SEK     10.39980     10.56330     10.44000     10.55630     10.61580
# IDR  15964.21000  16083.35000  15565.65000  15712.00000  15512.47000
# INR     81.83950     78.52400     79.81200     77.22050     78.93700
# BRL      4.19420      4.35110      4.51280      4.21000      4.62950
# ...

# %%
# List of Currency Names

cur_names = list(df_data.index)
cur_names[:5]
# Out:
# ['CAD', 'HKD', 'ISK', 'PHP', 'DKK']

# %%
# Sorting columns based on dates

df_data = df_data.sort_index(axis=1)
df_data.head(5)
# Out:
#      2019-01-02  2019-01-03  2019-01-04  2019-01-07  2019-01-08  2019-01-09  \
# CAD      1.5547      1.5392      1.5328      1.5281      1.5208      1.5172
# HKD      8.9294      8.8884      8.9325      8.9677      8.9671      8.9789
# ISK    133.4000    133.6000    134.0000    135.2000    136.1000    136.9000
# PHP     59.8940     59.6790     59.8090     59.9800     60.0570     59.8870
# DKK      7.4669      7.4675      7.4679      7.4675      7.4663      7.4661
#
#      2019-01-10  2019-01-11  2019-01-14  2019-01-15  ...  2019-12-16  \
# CAD      1.5251      1.5247      1.5226      1.5154  ...      1.4621
# HKD      9.0414      9.0427      8.9934      8.9594  ...      8.6856
# ISK    137.1000    138.1000    138.5000    138.5000  ...    136.8000
# PHP     60.1670     60.2060     59.9120     59.5190  ...     56.4210
# DKK      7.4655      7.4643      7.4639      7.4638  ...      7.4731
#
#      2019-12-17  2019-12-18  2019-12-19  2019-12-20  2019-12-23  2019-12-24  \
# ...

# %%
#All Jan dates
#01 denotes JAN
cur_dates = df_data.columns
jan_cur_dates = [dates for dates in cur_dates if dates[5:7] == '01' ]
print(jan_cur_dates)
# Out:
# ['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31']

# %%
#contains Jan details of all Currency 

jan_df_dates = df_data[X]
jan_df_dates
# Out:
#       2019-01-02   2019-01-03   2019-01-04  2019-01-07   2019-01-08  \
# CAD      1.55470      1.53920      1.53280      1.5281      1.52080
# HKD      8.92940      8.88840      8.93250      8.9677      8.96710
# ISK    133.40000    133.60000    134.00000    135.2000    136.10000
# PHP     59.89400     59.67900     59.80900     59.9800     60.05700
# DKK      7.46690      7.46750      7.46790      7.4675      7.46630
# HUF    322.37000    322.41000    321.45000    321.1100    322.15000
# CZK     25.75200     25.68300     25.65300     25.5720     25.64200
# AUD      1.62730      1.62870      1.61890      1.6040      1.60420
# RON      4.66000      4.66600      4.66560      4.6625      4.67100
# SEK     10.21450     10.28080     10.24600     10.2235     10.18550
# IDR  16484.11000  16352.47000  16241.35000  16122.6300  16181.88000
# INR     79.98550     79.60800     79.43150     79.6895     80.24500
# BRL      4.39300      4.28140      4.28890      4.2289      4.26040
# ...

# %%
#List of all INR rate exchange of 1-Jan-2019 -> 30-Jan-2019 Month
X = jan_cur_dates
Y = list(jan_df_dates.loc['INR'])

# %%
print(X)
# Out:
# ['2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31']

# %%
print(Y)
# Out:
# [79.9855, 79.608, 79.4315, 79.6895, 80.245, 80.6365, 81.2005, 81.3475, 81.2195, 81.231, 81.0055, 80.9765, 81.0875, 80.9335, 81.046, 81.0535, 80.656, 80.634, 81.232, 81.306, 81.351, 81.686]

# %%
# plot X and Y 

import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(X, Y, color='blue', linestyle='solid', linewidth = 3, 
         marker='o', markerfacecolor='red', markersize=7,label="INR") 
plt.legend()

plt.xticks( rotation = 90)
plt.xlabel('Dates',fontsize=10) 
plt.ylabel('INR',fontsize=10)
plt.grid('true')
plt.title('INR exchange rate against EUR from 1 Jan 2019 to 31 Jan 2019') 

plt.show()

# %%
# convert data to dictionary

# %%
data = {}

for i in range(len(X)):
    print(i)

# %%
import webbrowser
webbrowser.open('http://localhost:1234/winsoft.html', new=2)

# %%
# F-1
# using REST call to dynamically retrieve exchange rates
# REST uri - api.exchangeratesapi.io

import requests
url = 'https://api.exchangeratesapi.io/history?start_at=2020-01-01&end_at=2020-01-31&base=EUR&symbols=INR'

response = requests.get(url)
content = response.text
json_content = json.loads(content)
print(file_content)

# save to file as visual.json
file = open('visual.json','w')
file.write(str(json_content))
file.close()
# Out:
# {'rates': {'2020-01-07': {'INR': 80.265}, '2020-01-08': {'INR': 79.709}, '2020-01-20': {'INR': 78.784}, '2020-01-29': {'INR': 78.417}, '2020-01-03': {'INR': 80.0085}, '2020-01-21': {'INR': 79.1345}, '2020-01-14': {'INR': 78.7285}, '2020-01-10': {'INR': 78.6915}, '2020-01-31': {'INR': 78.9055}, '2020-01-13': {'INR': 78.8225}, '2020-01-17': {'INR': 78.9567}, '2020-01-27': {'INR': 78.7425}, '2020-01-24': {'INR': 78.67}, '2020-01-15': {'INR': 78.8825}, '2020-01-06': {'INR': 80.5175}, '2020-01-22': {'INR': 78.8665}, '2020-01-09': {'INR': 79.162}, '2020-01-16': {'INR': 79.221}, '2020-01-02': {'INR': 79.9065}, '2020-01-28': {'INR': 78.4545}, '2020-01-30': {'INR': 79.011}, '2020-01-23': {'INR': 79.0965}}, 'start_at': '2020-01-01', 'base': 'EUR', 'end_at': '2020-01-31'}
